# %%
UnderStanding of Variables

# %%
a=2
b=3

# %%
c=a+b
print(c)
# Out:
# 5

# %%
Rule1: No Name Space in Variable

# %%
first Name = 'Somu'
print(first Name)
# Out:
#   Cell In[2], line 1
#     first Name = 'Somu'
#           ^
# SyntaxError: invalid syntax

# %%
firstName = 'Somu'
print(firstName)
# Out:
# Somu

# %%
Rule 2:  Variable should not start with Number

# %%
1Name='Vamsi'
print(1Name)
# Out:
#   Cell In[6], line 1
#     1Name='Vamsi'
#     ^
# SyntaxError: invalid decimal literal

# %%
Name1='Vamsi'
print(Name1)
# Out:
# Vamsi

# %%
Rule 3 : Varible name should not contain special Symbols

# %%
test@='Somu'
print(test@)
# Out:
#   Cell In[10], line 2
#     print(test@)
#                ^
# SyntaxError: invalid syntax

# %%
test*='Somu'
print(test*)
# Out:
#   Cell In[12], line 2
#     print(test*)
#                ^
# SyntaxError: invalid syntax

# %%
Sting Declartion Single Qoute and Double Quote

# %%
name ='Somu'
print(name)
# Out:
# Somu

# %%
name ="Somu"
print(name)
# Out:
# Somu

# %%
String Methods

# %%
type(name)
# Out:
# str

# %%
fullname='somu vamsi krishna'
print(fullname)
# Out:
# somu vamsi krishna

# %%
print(fullname.title())
# Out:
# Somu Vamsi Krishna

# %%
print(fullname.upper())
# Out:
# SOMU VAMSI KRISHNA

# %%
print(fullname.lower())
# Out:
# somu vamsi krishna
